# %% [markdown]
# <a href="https://colab.research.google.com/github/moschenotavio0-debug/ALGESTDADOS20261/blob/main/exercicios%3A/Exercicio_fixa%C3%A7%C3%A3o12_03.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#---digite e execute linha a linha----------

a = 10
b = 3

print(a+b)   #adição
print(a-b)   #subtração
print(a*b)   #multiplicação
print(a/b)   #divsão real
print(a//b)  #divisão int.
print(a%b)   #módulo (resto de 10/3)
print(a**b)  #potenciação

#Qual a diferença entre / e // ?
#Por que a / b não da 3 exato?
# Out:
# 13
# 7
# 30
# 3.3333333333333335
# 3
# 1
# 1000

# %%
#---execute linha a linha e proveja o resultado antes ---

nota = 7.5

print(nota >= 6.0)  # ? (aprovado?)
print(nota == 10.0) # ? (nota maxima?)
print(nota != 5.0)  # ? (diferente de 5?)
print(nota < 5.0)   # ? (reprovado?)

#O que achou dos resultados? refletiram a realidade?
#E se alterrassemos a nota para 5.0?

nota = 5

print(nota >= 6.0)  # ? (aprovado?)
print(nota == 10.0) # ? (nota maxima?)
print(nota != 5.0)  # ? (diferente de 5?)
print(nota < 5.0)   # ? (reprovado?)
# Out:
# True
# False
# True
# False
# False
# False
# False
# False

# %%
#--troque os valores e observe o que muda----------
idade = 17
renda = 1500.0

# and - as DUAS precisam ser True
print(idade >=18 or renda >= 1200)  # ?

#or - BASTA UMA ser True
print(idade >= 18 or renda >= 1200)  # ?

#not - inverte
tem_debito = False
print(not tem_debito)  # ?
# Out:
# True
# True
# True

# %%
#--preveja o resultado de cada expressão----------

print(2 + 3 *4) # ? - qual operador executa primeiro?
print(( 2 + 3) * 4) # ? - parênteses mudam tudo!
print( 2 ** 3 **2)  # ? - ** associa da DIREITA  p/ esquerda
print( 10 / 2 + 3)  # ?
print(10 / (2 + 3)) # ? - mesma conta, resultado diferente!

#Expressão mista (aritmético + relacional + logico):
x = 3 + 2 * 4 > 10 and not False
# maior aritmético primeiro, depois relacional, depois lógico
print(x) # ?
# Out:
# 14
# 20
# 512
# 8.0
# 2.0
# True

# %%
#1- Declare duas variáveis a = 15 e b = 4. Calcule e exiba o resultado de todas as operações aritméticas: +, -, *, /, //, % e **.

a = 15
b= 4

print( a + b)
print(a - b)
print(a * b)
print(a / b)
print(a // b)
print(a % b)
print(a ** b)
# Out:
# 19
# 11
# 60
# 3.75
# 3
# 3
# 50625

# %%
#2- Um professor deseja dividir 37 alunos em grupos iguais de 5. Usando operadores aritméticos, descubra:
#quantos grupos completos serão formados?
#quantos alunos sobrarão?

alunos = 37
grupos = 5

print(f"serao dividos {alunos // grupos} grupos iguais")
print(f" sobrarão {alunos % grupos} alunos")
# Out:
# serao dividos 7 grupos iguais
#  sobrarão 2 alunos

# %%
#3- Calcule a área de um retângulo com base 8.5 e altura 3.2. Exiba o resultado com a mensagem:

base = 8.5
altura = 3.2
print(f"a área do retângulo é {base * altura}")
# Out:
# a área do retângulo é 27.200000000000003

# %%
#4- Dado o valor:
#segundos = 9875
#Use // e % para converter esse valor em horas, minutos e segundos. Exemplo de saída:
#2h 44min 35seg

segundos = 9874
minutos = segundos // 60
segundos = segundos % 60
horas = minutos // 60
minutos = minutos % 60

print(f'{horas}h {minutos}m e {segundos}s')
# Out:
# 2h 44m e 34s

# %%
#5- Calcule:
#2 ** 10 e explique com um comentário no código o que essa operação representa. Depois calcule a raiz quadrada de 144 usando potenciação.

conta = 2**10
print(f' o resultado da operação 2**10 é {conta}, pois ela esta significando o quanto e dois elevado a 10.')
raiz = 144**0.5
print(f' o resultado de 144 elevado a 0.5 é de {raiz}, o que é mesmo da raiz quadrada de 144')
# Out:
#  o resultado da operação 2**10 é 1024, pois ela esta significando o quanto e dois elevado a 10.
#  o resultado de 144 elevado a 0.5 é de 12.0, o que é mesmo da raiz quadrada de 144

# %%
#6- Crie uma variável:
#temperatura = 38.5
#Use operadores relacionais para verificar:
#se a temperatura é maior que 37.5
#se a temperatura é igual a 36.5
#se a temperatura é diferente de 40.0

temperatura = 38.5
print(temperatura > 37.5)
print(temperatura == 36.5)
print(temperatura != 40.0)
# Out:
# True
# False
# True

# %%
#7-
x = 10
y = 10
# Preveja o resultado antes de executar e depois confirme no Python:
print(x == y) #True
print(x != y) #False
print(x >= y) #True
print(x <= y + 1) #True
# Out:
# True
# False
# True
# True

# %%
#8- Um aluno tirou nota 6.5. Usando operadores relacionais, verifique se ele:
#foi aprovado (>= 7.0)
#está em recuperação (>= 5.0 e < 7.0)
#foi reprovado (< 5.0)
#Use print() para exibir cada verificação.

nota = 6.5
aprovado =  nota >= 7.0
recuperação = nota >= 5.0 and nota < 7.0
reprovado = nota < 5.0
print(f'o aluno foi aprovado?:{aprovado}')
print(f'o aluno esta em recuperação?: {recuperação}')
print(f'o aluno foi reprovado?: {reprovado}')
# Out:
# o aluno foi aprovado?:False
# o aluno esta em recuperação?: True
# o aluno foi reprovado?: False

# %%
#9- Declare: compare a e b e explique o resultado com um comentário no código.

a = 5
b = "5"

print(5 == "5")
print(f'O resultado da falso, pois o 5 representa um numero inteiro, já o "5", ele representa caracteres')
# Out:
# False
# O resultado da falso, pois o 5 representa um numero inteiro, já o "5", ele representa caracteres

# %%
#10- Crie um programa com um preco e depois verifique se o produto está dentro do orçamento de R$ 50,00 usando <=.

preco = 49.90
orçamento = preco <= 50.00
print(f' o produto esta dentro do orçamento?: {orçamento}')
# Out:
#  o produto esta dentro do orçamento?: True

# %%
#11- Uma pessoa pode votar se tiver 16 anos ou mais. Use operadores lógicos para verificar se ela não pode votar. Depois teste com:

idade1 = 15
votar = idade1 >= 16
print(f'A pessoa que tem 15 anos pode votar?: {votar}')

idade2 = 18
votar = idade2 >= 16
print(f'A pessoa que tem 18 anos pode votar?: {votar}')
# Out:
# A pessoa que tem 15 anos pode votar?: False
# A pessoa que tem 18 anos pode votar?: True

# %%
#12-Um empréstimo é aprovado se:
# renda >= 2000
# score >= 700
# Teste pelo menos três combinações diferentes usando and.

# Teste 1
renda = 1900 #renda menor
score = 500 #score menor
print(f'Meu score é {score} e minha renda é R${renda}. Empréstimo aprovado? {score >= 700 and renda >= 2000}')

# Teste 2
renda = 4000 #renda maior
score = 700 #score igual
print(f'Meu score é {score} e minha renda é R${renda}. Empréstimo aprovado? {score >= 700 and renda >= 2000}')

# Teste 3
renda = 1500 #renda maior
score = 850 #score menor
print(f'Meu score é {score} e minha renda é R${renda}. Empréstimo aprovado? {score >= 700 and renda >= 2000}')
# Out:
# Meu score é 500 e minha renda é R$1900. Empréstimo aprovado? False
# Meu score é 700 e minha renda é R$4000. Empréstimo aprovado? True
# Meu score é 850 e minha renda é R$1500. Empréstimo aprovado? False

# %%
#13- Um sistema libera acesso se o usuário for administrador ou tiver nível de acesso ≥ 3.

admin = False
nivel = 4

acesso = admin == True or nivel >= 3
print(f'O usuário terá o acesso liberado?: {acesso}')
# Out:
# O usuário terá o acesso liberado?: True

# %%
#14- Dado:
#chovendo = True
#Use not para verificar se não está chovendo. Depois combine com uma verificação de temperatura maior que 25.

chuva = True
print(not chuva)
# Out:
# False

# %%
#15-Monte manualmente a tabela-verdade do operador and:

print('Tabela-verdade do operador AND')
print('  A           B         C')
print(f'True   and  True   =  {True and True}')
print(f'True   and  False  =  {True and False}')
print(f'False  and  True   =  {False and True}')
print(f'False  and  False  =  {False and False}')
# Out:
# Tabela-verdade do operador AND
#   A           B         C
# True   and  True   =  True
# True   and  False  =  False
# False  and  True   =  False
# False  and  False  =  False

# %%
#16-Calcule manualmente antes de executar:
#a - 5 + 2 * 3 #11
#b - (5 + 2) * 3 #21
#c - 2 ** 3 ** 2 #512
#d - 10 - 4 / 2 + 1 #9

#Explique a ordem de execução nos comentários.
print(5 + 2 * 3) #11
print((5 + 2) * 3) #21
print(2 ** 3 ** 2) #512
print(10 - 4 / 2 + 1) #9

11
21
512
9.0
# Out:
# 11
# 21
# 512
# 9.0
# 9.0

# %%
#17- Resolva passo a passo:
#resultado = 3 + 2 * 4 ** 2 - 1
#Reescreva usando parênteses para mostrar a ordem das operações.

conta1 = 3 + 2 * 4 ** 2 - 1
conta2 = 3 + 2 * (4 ** 2) - 1

print(f' o resultado da conta 1 é: {conta1}')
print(f' o resultado da conta 2 é: {conta2}')
# Out:
#  o resultado da conta 1 é: 34
#  o resultado da conta 2 é: 34

# %%
#18- Analise o resultado da expressão abaixo antes de executar:
x = 4 + 3 * 2 > 9 and not (5 == 5)
print(x)
#Resposta: Para a expressão AND ser False, basta que uma das proposições "not(5==5)" seja False
# Out:
# False

# %%
#19-Reescreva usando parênteses para obter os resultados indicados:
a = 10 / (2 + 3)
print(a) #2

b = not (True or False)
print(b) #False
# Out:
# 2.0
# False

# %%
#20- Crie uma expressão que use operadores aritméticos, relacionais e lógicos para resolver o problema:
#Um estudante é aprovado com distinção se a média de duas notas for maior ou igual a 9.0 e nenhuma das notas for menor que 7.0.

nota1 = 9.5
nota2 = 8.5
media = (9.5 + 8.5)/2
aprovação = media >= 9.0 or media > 7.0
print(f' O aluno foi aprovado?: {aprovação}')
# Out:
#  O aluno foi aprovado?: True
