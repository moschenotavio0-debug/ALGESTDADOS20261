# %% [markdown]
# <a href="https://colab.research.google.com/github/moschenotavio0-debug/ALGESTDADOS20261/blob/main/exercicios%3A/exercicio_19_03.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
numero = 10

if numero > 0:
    print("O número e positivo!")

print("Fim do programa")
#esta linha sempre executada
# Out:
# O número e positivo!
# Fim do programa

# %%
#verificador de maioridade

idade = int(input("Digite sua idade: "))

if idade >= 18:
  print("Você é maior de idade.")
  print("Pode dirigir e votar!")

else:
  print("Você é menor de idade.")
  print("Você não pode dirigir ainda.")

print("Verificação concluida!")
# Out:
# Digite sua idade: 18
# Você é maior de idade.
# Pode dirigir e votar!
# Verificação concluida!

# %%
nota = float(input("Digite a nota (0 a 10): "))

if nota >= 9.0:
  conceito = "A"
  status = "Excelente!"

elif nota >=7.0:
  conceito = "B"
  status = "Aprovado!"

elif nota >= 5.0:
  conceito = "C"
  status = "Recuperação"

else:
  conceito = "D"
  status = "Reprovado"

print(f'Conceito: {conceito} - {status}')
# Out:
# Digite a nota (0 a 10): 10
# Conceito: A - Excelente!

# %%
upper() - MAIUSCULAS
lower() - MINUSCULAS
capitalize() - CAPITULARES

# %%
#Número Positivo
#Peça um número inteiro ao usuário. Se o número for maior que zero, exiba a mensagem "O número é positivo!".

numero = int(input("digite um numero inteiro: "))

if numero > 0:
  print("O numero é positivo!")

else:
  print("O seu número não é um numero positivo!")
# Out:
# digite um numero inteiro: 10
# O numero é positivo!

# %%
#Maioridade
#Leia a idade do usuário. Se for maior ou igual a 18, exiba "Maior de idade", caso contrário, exiba "Menor de idade".

idade = int(input("Digite sua idade: "))

if idade >= 18:
  print("Você é maior de idade.")

else:
  print("Você é menor de idade.")
# Out:
# Digite sua idade: 18
# Você é maior de idade.

# %%
#Número Par
#Solicite um número inteiro. Verifique se ele é par (divisível por 2) e exiba uma mensagem informando o resultado.

numero = int(input("digite um numero: "))

if numero % 2 == 0:
  print("O seu numero é um numero par!")

else:
  print("Seu número não é um número par!")
# Out:
# digite um numero: 5
# Seu número não é um número par!

# %%
#Senha Correta
#Defina uma senha fixa no código (ex: "python123"). Peça a senha ao usuário. Se bater, exiba "Acesso permitido", senão "Acesso negado".

senha = input("Digite a senha: ")

if senha == "python123":
  print("Acesso permitido!")

else:
  print("Acesso negado!")
# Out:
# Digite a senha: python123
# Acesso permitido!

# %%
#Temperatura Quente
#Leia a temperatura em graus Celsius. Se for maior que 30, exiba "Está quente hoje!". Caso contrário, exiba "Temperatura agradável.

temperatura = float(input("Digite a temperatura: "))

if temperatura > 30:
  print("Está quente hoje!")

else:
  print("Temperatura agradável!")
# Out:
# Digite a temperatura: 29
# Temperatura agradável!

# %%
#Saldo Suficiente
#Defina um saldo fixo (ex: 100.0). Peça ao usuário um valor para saque. Se o valor for menor ou igual ao saldo, exiba "Saque realizado!", caso contrário, "Saldo insuficiente."

saldo = 100
valor = float(input("Digite o valor de seu saque: "))

if valor <= saldo:
  print("Saque realizado!")

else:
  print("Saldo insuficiente!")
# Out:
# Digite o valor de seu saque: 110
# Saldo insuficiente!

# %%
#Aprovação Simples
#Leia a nota de um aluno (0 a 10). Se a nota for maior ou igual a 5, exiba "Aprovado". Senão, exiba "Reprovado".

nota = float(input("Digite sua nota: "))

if nota >= 5:
  print("Aprovado!")

else:
  print("Reprovado!")
# Out:
# Digite sua nota: 10
# Aprovado!

# %%
#Número Zero
#Peça um número ao usuário. Exiba se o número é zero ou diferente de zero usando if/else.

numero = int(input("Digite um número:"))

if numero == 0:
  print("Seu número é zero!")

else:
  print("Seu número é diferente de zero!")
# Out:
# Digite um número:0
# Seu número é zero!

# %%
#Valor Truthy ou Falsy
#Peça um número ao usuário. Sem usar == 0, use o próprio valor como condição no if para exibir "O número é falsy (zero)" ou "O número é truthy (diferente de zero)".

numero = bool(int(input("Digite um número")))

if numero is True:
  print("o numero e truthy (diferente de zero: )")

else:
  print("O numero é falsy (zero)")
# Out:
# Digite um número1
# o numero e truthy (diferente de zero: )

# %%
#Luz do Semáforo
#Peça ao usuário para digitar a cor do semáforo ("verde" ou outra cor). Se for "verde", exiba "Pode avançar!", caso contrário, "Pare!".

cor = input("Digite a cor do semáfaro: ")

if cor. upper() == "VERDE":
  print("Pode avaçar!")

else:
  print("Pare!")
# Out:
# Digite a cor do semáfaro: VERDE
# Pode avaçar!

# %%
#Nome Vazio
#Leia o nome do usuário. Se o nome for uma string vazia (falsy), exiba "Nenhum nome digitado.", caso contrário, exiba "Olá, [nome]!" usando f-string.

nome = input("Digite seu nome: ")

if bool (nome) is False:
  print("Nenhum nome digitado!")

else:
  print(f'Olá {nome}!')
# Out:
# Digite seu nome:
# Nenhum nome digitado!

# %%
#Maior entre Dois
#Leia dois números inteiros. Exiba qual deles é o maior. Se forem iguais, exiba "Os números são iguais."

n1 = int(input("Digite o 1º número inteiro: "))
n2 = int(input("Digite o 2º número inteiro: "))

if n1 > n2:
  print(f"O maior numero é {n1}!")

elif n2 > n1:
  print(f"O maior número é {n2}!")

else:
  print("Os números saõ iguais")
# Out:
# Digite o 1º número inteiro: 1
# Digite o 2º número inteiro: 2
# O maior número é 2!

# %%
#Chuva e Guarda-Chuva
#Pergunte ao usuário "Está chovendo? (sim/nao)". Se a resposta for "sim", exiba "Leve o guarda-chuva!", senão, "Não precisa de guarda-chuva."

chuva = input("Está chovendo? (sim/não): ")

if chuva.upper () == "SIM":
  print("Leve o guarda-chuva!")

else:
  print("Não precisa levar o guarda-chuva!")
# Out:
# Está chovendo? (sim/não): sim
# Leve o guarda-chuva!

# %%
#Desconto de Aniversário
#Pergunte se hoje é o aniversário do usuário (resposta: "sim" ou "nao"). Se sim, exiba "Parabéns! Você tem 20% de desconto." Senão, "Sem desconto hoje."

desconto = input("Hoje é seu aniversário? responda com sim ou não: ")

if desconto == "sim":
  print("Parabéns! Você tem 20% de desconto.")

else:
  print("Sem desconto hoje.")
# Out:
# Hoje é seu aniversário? responda com sim ou não: sim
# Parabéns! Você tem 20% de desconto.

# %%
#Indentação Correta
#Crie um programa que leia um número. Dentro do bloco if, exiba duas mensagens diferentes (duas linhas de print). Fora do if, exiba uma terceira mensagem que sempre aparece. Demonstre o uso correto da indentação com 4 espaços.

numero = float(input("Digite um número: "))

if numero > 0:
  print("O número é positivo!")
  print("O seu número é diferente de zero!")

else:
  print("Seu número é negativo: ")


print("Fim do programa!")
# Out:
# Digite um número: 4
# O número é positivo!
# O seu número é diferente de zero!
# Fim do programa!
