# %% [markdown]
# <a href="https://colab.research.google.com/github/moschenotavio0-debug/ALGESTDADOS20261/blob/main/exercicios%3A/exercic%C3%ADos_07_05_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#1 - LISTA SLIDE (LISTA):

notas = ['6' , '6.5' , '7' , '5' , '9' ]
print(f'Lista base:')

print(f'a) A primeira nota é: {notas[0]} e a última nota é: {notas[-1]}')

notas[1] = 10
print(f'b) {notas}')

notas.append(9)
print(f'c) {notas}')

print(f'd) Quantidade de notas: {len(notas)}')
# Out:
# Lista base:
# a) A primeira nota é: 6 e a última nota é: 9
# b) ['6', 10, '7', '5', '9']
# c) ['6', 10, '7', '5', '9', 9]
# d) Quantidade de notas: 6

# %%
#2 - LISTA SLIDE (LISTA):

nomes = ['Ana' , 'João' , 'Maria' , 'Vitor']
#a)
print('Letra A')
for nome in nomes:
    print(f'Presente: {nome}')
nomes.append('Otávio')

#b)
print('\nletraB')
for nome in nomes:
    print(f'Presente: {nome}')
# Out:
# Letra A
# Presente: Ana
# Presente: João
# Presente: Maria
# Presente: Vitor
#
# letraB
# Presente: Ana
# Presente: João
# Presente: Maria
# Presente: Vitor
# Presente: Otávio

# %%
#3 - LISTA SLIDE (LISTA):

numeros = ['1', '2' , '3' , '4' , '5' ,'6']

numeros.remove("3")
print(f'a){numeros}')

numeros.pop()
print(f'b) {numeros}')

numeros.sort()
print(f'c) {numeros}')

for i, valor in enumerate (numeros):
    print(f'{i+1}° nuúmero {valor}:')
# Out:
# a)['1', '2', '4', '5', '6']
# b) ['1', '2', '4', '5']
# c) ['1', '2', '4', '5']
# 1° nuúmero 1:
# 2° nuúmero 2:
# 3° nuúmero 4:
# 4° nuúmero 5:

# %%
#01 Contagem de Elementos
#Crie uma lista contendo os nomes de 5 vilões clássicos do Mario. Utilize a função len() para contar o número total de itens e exiba o resultado no terminal.

viloes = ["Bowser" , "King Boo" , "Wario" , "Bowser Jr." "Kamek"]

print(f"O número total de vilões é: {len(viloes)} vilões")
# Out:
# O número total de vilões é: 4 vilões

# %%
#02 - Adição Dinâmica
#Inicie uma lista vazia chamada moedas_coletadas. Use um laço de repetição para pedir que o usuário informe 4 valores inteiros e adicione cada um deles ao final da lista usando append().

moedas_coletadas = []

for i in range(4):
   valor = int(input(f"Digite o {i+1}° valor: "))
   moedas_coletadas.append(valor)

print(moedas_coletadas)
# Out:
# Digite o 1° valor: 1
# Digite o 2° valor: 2
# Digite o 3° valor: 3
# Digite o 4° valor: 4
# [1, 2, 3, 4]

# %%
#03 - Inserção por Posição
#Crie a lista herois = ['Mario', 'Peach']. Utilize o método insert() para adicionar o nome 'Luigi' exatamente no meio da lista (índice 1) e exiba a lista final.

herois = ["Mário" , "Peach"]

herois.insert(len(herois)//2, "Luigi")
print(herois)
# Out:
# ['Mário', 'Luigi', 'Peach']

# %%
#04 - Exclusão por Nome
#Dada a lista viloes = ['Bowser', 'Goomba', 'Wario', 'Koopa'], solicite que o usuário digite um nome. Se o nome estiver na lista, use remove() para excluí-lo.

viloes = ['Bowser', 'Goomba', 'Wario', 'Koopa']

nome = input("Digite um nome: ")

if nome in viloes:
    viloes.remove(nome)
    print(viloes)

else:
    print(viloes)
# Out:
# Digite um nome: Koopa
# ['Bowser', 'Goomba', 'Wario']

# %%
#05 - Remover o Último Elemento
#Crie uma lista com nomes de 4 itens de poder (ex: Estrela, Cogumelo). Use pop() para remover o último item e mostre qual item foi removido e como a lista ficou.

powers = ["Estrela" , "Cogumelo Vermelho" , "Flor de Fogo" , "Pena"]
removido = powers[-1]
powers.pop()
print(f"Foi removido {removido} \ne a lista ficou: {powers}!")
# Out:
# Foi removido Pena
# e a lista ficou: ['Estrela', 'Cogumelo Vermelho', 'Flor de Fogo']!

# %%
#06 - Ordenação de Fases
#Peça 5 pontuações ao usuário e armazene-as. Utilize sort() para ordenar a lista em ordem crescente e exiba-a organizada.

pontuacoes = [i]
for i in range(5):
    ponto = float(input(f"Digite a {i+1}° nota: "))
    pontuacoes.append(ponto)

pontuacoes.sort
print(pontuacoes)
# Out:
# Digite a 1° nota: 6
# Digite a 2° nota: 4
# Digite a 3° nota: 3
# Digite a 4° nota: 1
# Digite a 5° nota: 9
# [3, 6.0, 4.0, 3.0, 1.0, 9.0]

# %%
#07 - Mapeando o Castelo
#Crie uma lista com 4 nomes de fases. Use enumerate() dentro de um for para exibir o índice e o nome de cada fase (Ex: "Fase 0: Castelo de Fogo").

# %%
#12 -  #Loop com Índice
#Crie uma lista de 5 itens. Use enumerate() para exibir: "Item X na posição Y", onde X é o valor e Y é o índice.

lista = ['Mario' , 'Luigi' , 'peach' , 'toad' , 'bowser']
for indice, personagem in enumerate(lista):
    print(f'{personagem} na posição {indice}')
# Out:
# Mario na posição 0
# Luigi na posição 1
# peach na posição 2
# toad na posição 3
# bowser na posição 4

# %%
#13 - Remover Item Específico
#Crie uma lista poderes = ['Fogo', 'Gelo', 'Voo']. Peça ao usuário qual poder ele deseja descartar e utilize remove() para realizar a ação.

poderes = ['fogo' , 'gelo' , 'voo']
descarte = input('Digite o poder de ser descartado: ')

if descarte in poderes:
    poderes.remove(descarte)

else:
    print('Poder não listado')

print(poderes)
# Out:
# Digite o poder de ser descartado: fogo
# ['gelo', 'voo']

# %%
#14 - Controle de Inventário
#Peça para o usuário digitar 5 nomes de itens. Adicione-os à lista e no final use um if com len() para verificar: se a lista tiver mais de 3 itens, exiba "Mochila Cheia".

itens = []
for i in  range(5):
    valor = input(f'Digite o {i+1}° um item: ')
    itens.append(valor)

if len(itens) > 3:
    print('Mochila Cheia')
# Out:
# Digite o 1° um item: cogumelo
# Digite o 2° um item: maça
# Digite o 3° um item: pena
# Digite o 4° um item: britadeira
# Digite o 5° um item: flor
# Mochila Cheia

# %%
#15 - Organização Final
#Crie uma lista com 3 números. Use insert() para adicionar um novo número no índice 0 e depois use sort() para garantir que fiquem em ordem crescente.

numero = [7 , 9 , 1]
numero.insert(0,8)
numero.sort()
print(numero)
# Out:
# [1, 7, 8, 9]
