# %% [markdown]
# <a href="https://colab.research.google.com/github/moschenotavio0-debug/ALGESTDADOS20261/blob/main/exercicios%3A/exercicios_23_03_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#01 - Conceito Escolar
#Leia a nota de um aluno. Classifique usando elif: nota ≥ 9 → "A — Excelente", ≥ 7 → "B — Aprovado", ≥ 5 → "C — Recuperação", abaixo → "D — Reprovado".

nota = float(input("Digite sua nota: "))

if 10 >= nota >= 9:
    print("A - Execelente")

elif 10 > nota >= 7:
    print("B - Aprovado")

elif 10 > nota >= 5:
    print("C - Recuperação")

elif 10 > nota >= 0:
    print("D - Reprovado")

else:
    print("Nota inválida")
# Out:
# Digite sua nota: 10
# A - Execelente

# %%
#02 - Dias da Semana
#Leia um número de 1 a 7 e exiba o nome do dia correspondente (1 = Segunda, ..., 7 = Domingo). Para qualquer outro número, exiba "Número inválido".

dia = int(input("Digite um numero de 1 a 7 para representar o dia da semana: "))

match dia:
    case 1: print("Domingo")
    case 2: print("segunda-feira")
    case 3: print("terça-feira")
    case 4: print("quarta-feira")
    case 5: print("quinta-feira")
    case 6: print("sexta-feira")
    case 7: print("sábado")
    case _ : print("dia não válido")
# Out:
# Digite um numero de 1 a 7 para representar o dia da semana: 5
# quinta-feira

# %%
#3 - Nota Válida
#Leia uma nota. Valide se está entre 0 e 10 usando encadeamento de comparações (0 <= nota <= 10). Se inválida, exiba "Nota inválida!". Se válida, exiba "Nota registrada: [nota]".

nota = float(input("Digite a nota: "))

if 10 >= nota >= 0:
    print(f"Nota registrada: {nota}")

else:
    print("Nota inválida!")
# Out:
# Digite a nota: 6
# Nota registrada: 6.0

# %%
#4 - Faixa Etária
#Leia a idade. Classifique: menor de 12 → "Criança", 12 a 17 → "Adolescente", 18 a 59 → "Adulto", 60 ou mais → "Idoso". Valide que a idade não é negativa.

idade = int(input("Digite sua idade: "))

if 0<= idade <= 12:
    print("Criança")

elif 0 <= idade < 18:
    print("Adolescente")

elif 0 <= idade < 60:
    print("Adulto")

elif 0 <= idade:
    print("Idoso")

else:
    print("Idade Negativa?")
# Out:
# Digite sua idade: 18
# Adulto

# %%
#5 - Cardápio com Validação
#Exiba um menu com 3 opções (ex: 1-Água R$2, 2-Suco R$6, 3-Café R$4). Leia a escolha. Valide com not (1 <= item <= 3). Se inválido, exiba erro; se válido, exiba o item e o preço

item = int(input("menu\n1-Água R$2\n2-Suco R$6\n3-Café R$4\nEscolha o item: "))

if not (1<= item <=3):
    print("Erro")

else:
    match item:
        case 1: print("Você adquiriu uma Água!")
        case 2: print("Você adquiriu um Suco!")
        case 3: print("Você adquiriu um Café!")
# Out:
# menu
# 1-Água R$2
# 2-Suco R$6
# 3-Café R$4
# Escolha o item: 3
# Você adquiriu um Café!

# %%
#6 - Leia a temperatura. Classifique usando elif: abaixo de 0 → "Congelante", 0 a 15 → "Frio", 16 a 25 → "Agradável", 26 a 35 → "Quente", acima de 35 → "Muito quente".

temperatura = float(input("digite a temperatura: "))

if temperatura <0:
    print("Congelante")

elif temperatura <=15:
    print("Frio")

elif temperatura <=25:
    print("Agradável")

elif temperatura <=35:
    print("Quente")

else:
    print("Muito quente")
# Out:
# digite a temperatura: 30
# Quente

# %%
#7 - Leia dois números e um operador (+, -, *, /). Use elif para realizar a operação correta. Valide a divisão por zero. Para operador inválido, exiba "Operador desconhecido".

try:
    num1 = float(input("Digite um número: "))
    operador = input("Digite a operação (/*-+): ")
    num2 = float(input("Digite um número: "))

    if operador == '+':
        resultado = num1 + num2
        print(f"{num1} + {num2} = {resultado}")

    elif operador == '-':
        resultado = num1 - num2
        print(f"{num1} - {num2} = {resultado}")

    elif operador == '*':
        resultado = num1 * num2
        print(f"{num1} * {num2} = {resultado}")

    elif operador == '/':
      if num2 == 0:
        print("Erro: Divisão por zero!")
      else:
        resultado = num1 / num2
        print(f"{num1} / {num2} = {resultado}")

    else:
        print("Operador desconhecido")

except:
    print("Erro: Entrada inválida. Certifique-se de digitar números.")
# Out:
# Digite um número: 1
# Digite a operação (/*-+): +
# Digite um número: 2
# 1.0 + 2.0 = 3.0

# %%
#8 - Acesso com Dupla Validação
#Defina um usuário e senha corretos no código. Leia usuário e senha. Somente se ambos estiverem corretos (usando and), exiba "Login efetuado!". Caso contrário, "Usuário ou senha incorretos."

usuario = "Otavio"
senha = "1234"
usuario = input("digite seu usuário: ")
senha = input("digite a senha: ")

if usuario == "Otavio" and senha == "1234":
  print("Login efetuado!")

else:
  print("Usuário ou senha incorreta!")
# Out:
# digite seu usuário: otavio
# digite a senha: 1234
# Usuário ou senha incorreta!

# %%
from re import A
#9 - Triângulo Válido
#Leia três lados. Valide primeiro se todos são maiores que zero. Em seguida, verifique se formam um triângulo (cada lado menor que a soma dos outros dois). Exiba o resultado.

ladoA = float(input("digite o tamanho do lado A: "))
ladoB = float(input("digite o tamanho do lado B: "))
ladoC = float(input("digite o tamanho do lado C: "))

if ladoA > 0 and ladoB < 0 and ladoC > 0:
    if (ladoA + ladoB) > ladoC and (ladoA + ladoB) > ladoB and (ladoB + ladoC) > ladoA:
        print("Formam um triangulo")

    else:
        print("Para formar um triangulo, cada lado tem que ser menor que a soma dos outros dois")

else:
    print("Triangulo não podem ter lados menores ou iguais a 0")
# Out:
# digite o tamanho do lado A: 5
# digite o tamanho do lado B: 3
# digite o tamanho do lado C: 2
# Triangulo não podem ter lados menores ou iguais a 0

# %%
#10 - Desconto por Faixa de Compra
#Leia o valor de uma compra. Valide que é positivo. Aplique: ≥ R$500 → 15%, ≥ R$200 → 10%, ≥ R$100 → 5%, abaixo → 0%. Exiba o desconto e o valor final.

valor = float(input("Valor da compra"))
if 0 < valor < 100:
    print(f"R$ {valor: .2f} - sem desconto")

elif 0 < valor < 200:
    print(f" R$ {(valor * 0.95):.2f} - 5% de desconto")

elif 0 < valor < 500:
    print(f" R$ {(valor * 0.90):.2f}")

elif 0 < valor:
    print(f" R$ {(valor * 0.85):.2f}")

else:
    print("Compra inválida")
# Out:
# Valor da compra510
#  R$ 433.50

# %%
#11 - Estação do Ano
#Leia o número do mês (1 a 12). Use elif para exibir a estação do ano correspondente. Use or para agrupar os meses de cada estação. Valide o mês (1 a 12).

mes = int(input("Digite número do mês (1 a 12): "))

if mes == 12 or mes == 2 or mes == 3:
  print("A estação do ano é verão")

elif mes == 4 or mes == 5 or mes == 6 or mes == 7:
  print("A estação do ano é outono")

elif mes == 8 or mes == 9 or mes == 10:
  print("A estação é inverno")

else:
  print("A estação do ano é primavera")
# Out:
# Digite número do mês (1 a 12): 3
# A estação do ano é verão

# %%
#12 - Número no Intervalo
#Leia dois números A e B (A menor que B) e um terceiro número N. Verifique se N está dentro do intervalo [A, B] usando encadeamento de comparações (A <= N <= B)

# %%
#13 - Tipo de Número
#Leia um número inteiro. Usando elif, classifique em: positivo e par, positivo e ímpar, negativo e par, negativo e ímpar, ou zero. Use o operador % para verificar paridade.

num = int(input("Digite um número inteiro: "))

if num == 0:
  print("Seu número é zero!")

elif num > 0 and num % 2 == 0:
  print("Seu número é positivo e par!")

elif num > 0 and num % 2 != 0:
  print("Seu número é positivo e impar!")

elif num < 0 and num % 2 == 0:
  print("Seu número é negativo e par!")

elif num < 0 and num % 2 != 0:
  print("Seu número é negativo e impar!")
# Out:
# Digite um número inteiro: -4
# Seu número é negativo e par!

# %%
#14 - Aprovação com Frequência
#Leia a nota (0-10) e a frequência (0-100%) de um aluno. Use and para verificar aprovação: nota ≥ 7 e frequência ≥ 75%. Se apenas um critério falhar, indique qual. Se ambos falharem, exiba "Reprovado em nota e frequência".

nota = float(input("Digite a nota do aluno: "))
frequencia = float(input("Digite a frequencia do aluno(%): "))

if nota >= 7 and frequencia >= 75:
  print("aprovado!")

elif nota >= 7 and frequencia < 75:
  print("Reprovado em frequencia")

elif nota < 7 and frequencia >= 75:
  print("Reprovado em nota!")

elif nota < 7 and frequencia < 75:
  print("Reprovado em nota e frequencia!")
# Out:
# Digite a nota do aluno: 10
# Digite a frequencia do aluno(%): 60
# Reprovado em frequencia

# %%
#15 - IMC Simplificado
#Leia peso (kg) e altura (m). Valide que peso > 0 e 0.5 <= altura <= 2.5. Calcule o IMC. Classifique em: Abaixo do peso (<18.5), Normal (18.5–24.9), Sobrepeso (25–29.9) e Obesidade (≥30). Exiba o IMC com 2 casas decimais e a classificação.
