# %% [markdown]
# <a href="https://colab.research.google.com/github/moschenotavio0-debug/ALGESTDADOS20261/blob/main/exercicos%3A/exercic%C3%ADos_18_05.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
aluno ={
    'nome': 'Ana Silva',
    'idade': 18,
    'curso': 'Informática' ,
    'média': 8.7
}

print(aluno['nome'])
# Out:
# Ana Silva

# %%
aluno ={
    'nome': 'Ana Silva',
    'idade': 18,
    'curso': 'Informática' ,
    'média': 8.7
}

lista = []
lista.append(aluno)

print(lista[0] ['nome'], (lista[0] ['idade']))
# Out:
# Ana Silva 18

# %%
lista = []

for i in range (5):
    nome = input("Digite o nome o nome do aluno: ")
    data_nasc = input("Digite a data de nascimento: ")
    curso = input("Digite o curso do aluno: ")

    aluno = {'nome': nome, 'data_nasc': data_nasc, 'curso': curso}
    lista.append(aluno)
    print('Aluno adiconado com sucesso! \n')

    print(lista[0] ['nome'], (lista[0] ['data_nasc'], (lista[0] ['curso'])))
