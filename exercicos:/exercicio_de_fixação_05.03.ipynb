# %% [markdown]
# <a href="https://colab.research.google.com/github/moschenotavio0-debug/ALGESTDADOS20261/blob/main/exercicos%3A/exercicio_de_fixa%C3%A7%C3%A3o_05.03.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#1 - Peça ao usuário que digite sua idade usando input(), converta o valor para inteiro utilizando int() e exiba na tela a idade somada com 5 anos = int(input(""))

idade = int(input("digite a sua idade:"))
print (f" {idade + 5} anos")
# Out:
# digite a sua idade:18
#  23 anos

# %%
#2 - Solicite ao usuário sua altura em metros, converta o valor digitado para float e mostre o dobro da altura informada.

altura = float(input("digite sua altura (m):"))
print (f"o dobro da sua altura e {altura*2} metros")
# Out:
# digite sua altura (m):1.71
# o dobro da sua altura e 3.42 metros

# %%
#3 - Crie uma variável inteira com valor 100, converta esse valor para str e concatene com a frase " pontos alcançados", exibindo o resultado final.

valor = 100
texto = str(valor)
print (texto + "pontos alcançados")
# Out:
# 100pontos alcançados

# %%
#4 - Peça ao usuário que digite 1 para verdadeiro ou 0 para falso, converta primeiro para inteiro e depois para bool, mostrando o valor booleano resultante.

opcao = bool(int(input("digite 1 para verdadeiro ou 0 para falso: ")))
print (opcao)
# Out:
# digite 1 para verdadeiro ou 0 para falso: 1
# True

# %%
#5 - Peça três números ao usuário, converta todos para inteiro e mostre o maior entre eles.

n1 = int(input("digite um numero:"))
n2 = int(input("digite um numero:"))
n3 = int(input("digite um numero"))
print (f"o maior numero e {max(n1,n2,n3)}")
# Out:
# digite um numero:1
# digite um numero:2
# digite um numero3
# o maior numero e 3

# %%
#6 - Peça quatro números decimais ao usuário, converta para float e calcule a média aritmética entre eles.

nd1 = float(input("digite um numero:"))
nd2 =float(input("digite um numero:"))
nd3 = float(input("digite um numero:"))
nd4 = float (input("digite um numero:"))
media = (f"a media entre {nd1}, {nd2}, {nd3}, {nd4}, e {((nd1 + nd2 + nd3 + nd4)/4):.2f}")
print (media)
# Out:
# digite um numero:2
# digite um numero:4
# digite um numero:6
# digite um numero:8
# a media entre 2.0, 4.0, 6.0, 8.0, e 5.00

# %%
#7 - Peça a idade do usuário em anos, converta para inteiro e calcule aproximadamente quantos meses essa pessoa já viveu.

idade = int(input("digite sua idade:"))
meses = idade*12
print(f"essa pessoa ja viveu {meses} meses, aproximadamente")
# Out:
# digite sua idade:18
# essa pessoa ja viveu 216 meses, aproximadamente

# %%
#8 - Peça ao usuário que digite um número inteiro, converta esse número para str e utilize a função len() para mostrar quantos caracteres foram digitados.

numero = str(int(input("digite um numero:")))
print(f"o numero {numero} tem {len(numero)} caracteres.")
# Out:
# digite um numero:12345
# o numero 12345 tem 5 caracteres.

# %%
#9 - Escreva um pequeno código que tente somar 1 a um valor recebido por input() sem realizar conversão, observe o erro gerado e depois corrija o código realizando a conversão adequada.try:

numero = input = str(int(input("digite um numero: "))) #string nao pode somado com numero inteiro
numero = int(numero) # precisa fazer a conversao para inteiro
numero += 1 # numero = numero + 1
print(numero)
# Out:
# digite um numero: 10
# 11

# %%
#10 - Peça um número decimal ao usuário, converta para float e depois converta esse valor para inteiro usando int(), exibindo ambos os resultados para comparar a diferença.


n1 = float(input("digite um numero decimal:"))
n2 = int(n1)

print(f"numero decimal digitado: {n1}")
print(f"numero convertido para inteiro:{n2}")
# Out:
# digite um numero decimal:25.5
# numero decimal digitado: 25.5
# numero convertido para inteiro:25

# %%
#11 - Solicite um número ao usuário, converta para inteiro e depois para bool, explicando em quais situações o resultado será False
numero = int(input("digite um numero: "))
boolean = bool(numero)
print(f"{boolean}, pois apenas valores de 0 ou vazio e false em python")
# Out:
# digite um numero: 1
# True, pois apenas valores de 0 ou vazio e false em python

# %%
#12 - Peça ao usuário uma temperatura em Kelvin, converta para float, transforme o valor para Celsius e exiba o resultado.

temp = float(input("digite a temperatura em kelvin: "))
celsius = (temp - 273.15)

print(f"a temperatura convertida para celsius é: {celsius}")
# Out:
# digite a temperatura em kelvin: 273.15
# a temperatura convertida para celsius é: 0.0

# %%
#13 - Desenvolva um pequeno programa que receba nome, idade e salário do usuário, convertendo idade para inteiro e salário para float, e mostre todas as informações organizadas na tela.

nome = (input("digite o seu nome: "))
idade = int(input("digite sua idade: "))
salario = float(input("digite seu salario: "))

print(f"seu nome e {nome},tem {idade} anos e voce recebe um salario de $ {salario} reais.")
# Out:
# digite o seu nome: Otavio
# digite sua idade: 18
# digite seu salario: 1300
# seu nome e Otavio ,tem 18 anos e voce recebe um salario de 1300.0 reais.

# %%
#14 - Solicite o preço de um produto e o percentual de desconto, converta ambos para float, calcule o valor final com desconto aplicado e exiba o resultado.

preco = float(input("digite o valor do produto: "))
desconto = float(input("digite o valor do percentual de desconto: "))
vf = preco - (preco *  desconto/100)
print(f"o valor do seu produto com desconto e de: {vf}")
# Out:
# digite o valor do produto: 100
# digite o valor do percentual de desconto: 12
# o valor do seu produto com desconto e de: 88.0

# %%
#15 - Peça ao usuário que digite um valor numérico, tente convertê-lo para inteiro e, caso ocorra erro de conversão, exiba uma mensagem informando que o valor digitado é inválido.

n1 = input("digite um valor numerico: ") #apenas numeros inteiros, caso seja decimais tem que converter para float
convertido = int(n1)
print (convertido)
# Out:
# digite um valor numerico: 5
# 5
